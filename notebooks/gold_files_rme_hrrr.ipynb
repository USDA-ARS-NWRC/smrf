# %% [markdown]
# # RME HRRR gold files
# This notebook plots the gold files for the RME HRRR test case to visually ensure that the files are as desired.

# %%
import netCDF4 as nc
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_context('talk')

# %%
# plot function

def plot_gold(variable):
    n = nc.Dataset('../tests/RME/gold_hrrr/{}.nc'.format(variable))
    tsteps = np.min([3, len(n.variables['time'])])

    fig, ax = plt.subplots(figsize=(15, 8), nrows=1, ncols=3)
    fig.subplots_adjust(left=0.02, bottom=0.06, right=0.95, top=0.9, wspace=0.05)
    fig.suptitle('RME HRRR {}'.format(variable))

    # get the dates
    dt = nc.num2date(n.variables['time'][:], n.variables['time'].units, n.variables['time'].calendar)

    vmin = np.min(n.variables[variable][:])
    vmax = np.max(n.variables[variable][:])
    print('Min: {}, Max: {}'.format(vmin, vmax))

    for i in range(tsteps):
        im = ax[i].imshow(n.variables[variable][i, :], vmin=vmin, vmax=vmax)

        im.axes.get_xaxis().set_ticks([])
        im.axes.get_yaxis().set_ticks([])
        ax[i].set_title(dt[i].strftime('%Y-%m-%d %H:%M'))

    fig.colorbar(im, ax=ax.ravel().tolist(), orientation="horizontal", shrink=0.5)

    n.close()

# %%
# air temp
plot_gold('air_temp')
# Out:
# Min: 19.126951217651367, Max: 22.517135620117188

# %%
plot_gold('net_solar')
# Out:
# Min: 5.65498685836792, Max: 305.8789367675781

# %%
plot_gold('percent_snow')
# Out:
# Min: 0.0, Max: 0.0

# %%
plot_gold('precip_temp')
# Out:
# Min: -4.785579681396484, Max: -2.1742823123931885

# %%
plot_gold('precip')
# Out:
# Min: 0.0, Max: 0.0

# %%
plot_gold('snow_density')
# Out:
# Min: 0.0, Max: 0.0

# %%
plot_gold('thermal')
# Out:
# Min: 255.2034149169922, Max: 393.9288024902344

# %%
plot_gold('vapor_pressure')
# Out:
# Min: 408.7171325683594, Max: 509.80145263671875

# %%
plot_gold('wind_direction')
# Out:
# Min: 199.23855590820312, Max: 261.23126220703125

# %%
plot_gold('wind_speed')
# Out:
# Min: 1.8307182788848877, Max: 3.2518599033355713
