# %% [markdown]
# # Lakes gold files
# This notebook plots the gold files for the Lakes test case to visually ensure that the files are as desired.

# %%
import netCDF4 as nc
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_context('talk')

# %%
# plt function

def plot_gold(variable):
    n = nc.Dataset('../tests/Lakes/gold_hrrr/{}.nc'.format(variable))
    tsteps = len(n.variables['time'])

    fig, ax = plt.subplots(figsize=(15, 8), nrows=1, ncols=3)
    fig.subplots_adjust(left=0.02, bottom=0.06, right=0.95, top=0.9, wspace=0.05)
    fig.suptitle('Lakes {}'.format(variable))

    # get the dates
    dt = nc.num2date(n.variables['time'][:], n.variables['time'].units, n.variables['time'].calendar)

    vmin = np.min(n.variables[variable][:])
    vmax = np.max(n.variables[variable][:])
    print('Min: {}, Max: {}'.format(vmin, vmax))

    for i in range(tsteps):
        im = ax[i].imshow(n.variables[variable][i, :], vmin=vmin, vmax=vmax)

        im.axes.get_xaxis().set_ticks([])
        im.axes.get_yaxis().set_ticks([])
        ax[i].set_title(dt[i].strftime('%Y-%m-%d %H:%M'))

    fig.colorbar(im, ax=ax.ravel().tolist(), orientation="horizontal", shrink=0.5)

    n.close()

# %%
# air temp
plot_gold('air_temp')
# Out:
# Min: -7.149078845977783, Max: 2.0818567276000977

# %%
plot_gold('net_solar')
# Out:
# Min: 0.03355206176638603, Max: 221.0450897216797

# %%
plot_gold('percent_snow')
# Out:
# Min: 0.0, Max: 0.0

# %%
plot_gold('precip_temp')
# Out:
# Min: -20.221431732177734, Max: -0.2940026819705963

# %%
plot_gold('precip')
# Out:
# Min: 0.0, Max: 0.0

# %%
plot_gold('snow_density')
# Out:
# Min: 0.0, Max: 0.0

# %%
plot_gold('thermal')
# Out:
# Min: 134.451416015625, Max: 295.344970703125

# %%
plot_gold('vapor_pressure')
# Out:
# Min: 101.00374603271484, Max: 596.23388671875

# %%
plot_gold('wind_direction')
# Out:
# Min: 7.322721558011835e-07, Max: 360.0

# %%
plot_gold('wind_speed')
# Out:
# Min: 0.44699999690055847, Max: 8.024999618530273
